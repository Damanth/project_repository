# %% [markdown]
# # Zomato Dataset Cleaning

# %%
import pandas as pd

# %%
data = pd.read_csv("zomato_dataset.csv")

# %%
data.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# ...

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
data.shape
# Out:
# (51717, 17)

# %% [markdown]
# ## 1)Deleting the redundent columns

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
columns_to_keep = ['name', 'online_order', 'book_table', 'rate','dish_liked','approx_cost(for two people)']
columns_to_drop = ['url', 'address','votes','phone', 'location', 'rest_type','cuisines','reviews_list', 'menu_item','listed_in(type)', 'listed_in(city)']

# %%
data.shape
# Out:
# (51717, 17)

# %%
len(columns_to_keep)
# Out:
# 6

# %%
len(columns_to_drop)
# Out:
# 11

# %% [markdown]
# ### 1st Way - Filtering Data

# %%
type(data["name"])
# Out:
# pandas.core.series.Series

# %%
columns_to_keep
# Out:
# ['name',
#  'online_order',
#  'book_table',
#  'rate',
#  'dish_liked',
#  'approx_cost(for two people)']

# %%
data[columns_to_keep]
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
new_data = data[columns_to_keep]

# %%
new_data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# ### 2nd way - Dropping the columns

# %%
data.drop(columns=columns_to_drop, inplace=True)

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# ## Remnaming the columns

# %% [markdown]
# ### 1)renaming one by one

# %%
data.rename(columns={'name':'name1','book_table':'book_table123'})
# data.rename(columns={'name':'name1'},inplace=True)
# Out:
#                                                    name1 online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table123    rate  \
# 0               Yes   4.1/5
# 1                No   4.1/5
# 2                No   3.8/5
# ...

# %% [markdown]
# ### 2)renaming all at once

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'dish_liked',
#        'approx_cost(for two people)'],
#       dtype='object')

# %%
data.columns[0].capitalize()
# Out:
# 'Name'

# %%
for i in data.columns:
    print(i.capitalize())
# Out:
# Name
# Online_order
# Book_table
# Rate
# Dish_liked
# Approx_cost(for two people)

# %%
new_data_columns = []
for i in data.columns:
    new_data_columns.append(i.capitalize())

new_data_columns
# Out:
# ['Name',
#  'Online_order',
#  'Book_table',
#  'Rate',
#  'Dish_liked',
#  'Approx_cost(for two people)']

# %%
data.columns = new_data_columns
data
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %% [markdown]
# ## Droppinng the duplicates

# %%
data.duplicated().sum()
# Out:
# np.int64(32808)

# %%
data.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
data.duplicated().tail(10)
# Out:
# 51707     True
# 51708     True
# 51709     True
# 51710     True
# 51711     True
# 51712     True
# 51713     True
# 51714    False
# 51715     True
# 51716     True
# dtype: bool

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Removing the NaN values from the data sheet

# %%
data.isna()
# Out:
#         Name  Online_order  Book_table   Rate  Dish_liked  \
# 0      False         False       False  False       False
# 1      False         False       False  False       False
# 2      False         False       False  False       False
# 3      False         False       False  False       False
# 4      False         False       False  False       False
# ...      ...           ...         ...    ...         ...
# 51631  False         False       False  False        True
# 51632  False         False       False  False        True
# 51641  False         False       False  False        True
# 51677  False         False       False  False       False
# 51714  False         False       False   True        True
#
#        Approx_cost(for two people)
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# ...

# %%
data.isna().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rate                            2418
# Dish_liked                     10587
# Approx_cost(for two people)      140
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Name                           0
# Online_order                   0
# Book_table                     0
# Rate                           0
# Dish_liked                     0
# Approx_cost(for two people)    0
# dtype: int64

# %%
data = data.reset_index(drop=True)
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#         Rate                                         Dish_liked  \
# ...

# %% [markdown]
# ## Cleaning Individual Columns

# %%
data["Rate"][12]
# Out:
# '4.0/5'

# %%
type(data["Rate"][12])
# Out:
# str

# %%
data["Rate"]
# Out:
# 0        4.1/5
# 1        4.1/5
# 2        3.8/5
# 3        3.7/5
# 4        3.8/5
#          ...
# 8245    2.5 /5
# 8246    3.6 /5
# 8247    3.8 /5
# 8248    4.2 /5
# 8249    2.5 /5
# Name: Rate, Length: 8250, dtype: object

# %%
data["Rate"] = data["Rate"].str.replace(' ','')
data["Rate"]
# Out:
# 0       4.1/5
# 1       4.1/5
# 2       3.8/5
# 3       3.7/5
# 4       3.8/5
#         ...
# 8245    2.5/5
# 8246    3.6/5
# 8247    3.8/5
# 8248    4.2/5
# 8249    2.5/5
# Name: Rate, Length: 8250, dtype: object

# %%
data["Rate"] = data["Rate"].str.replace('/5','')
data["Rate"]
# Out:
# 0       4.1
# 1       4.1
# 2       3.8
# 3       3.7
# 4       3.8
#        ...
# 8245    2.5
# 8246    3.6
# 8247    3.8
# 8248    4.2
# 8249    2.5
# Name: Rate, Length: 8250, dtype: object

# %% [markdown]
# ## Check for somemore transformations

# %%
data["Online_order"]
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3        No
# 4        No
#        ...
# 8245     No
# 8246     No
# 8247    Yes
# 8248     No
# 8249     No
# Name: Online_order, Length: 8250, dtype: object

# %%
data["Online_order"].apply(lambda x: 1 if x == "Yes" else 0 )
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 8245    0
# 8246    0
# 8247    1
# 8248    0
# 8249    0
# Name: Online_order, Length: 8250, dtype: int64

# %%
data["Online_order"] = data["Online_order"].apply(lambda x: 1 if x == "Yes" else 0 )

# %%
data
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
#      Rate                                         Dish_liked  \
# ...

# %%
data.to_csv("Cleaned_zomata_data.csv", index = False)

# %% [markdown]
# ## Generating Insights

# %%
# data
data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # data
# ----> 2 data.columns
#
# NameError: name 'data' is not defined

# %%
data["Rate"] = pd.to_numeric(data["Rate"], errors="coerce")
data["Rate"] = pd.to_numeric(data["Rate"], errors="coerce")

# %%
# Average ratings, cost, and popularity
print("Average Rating:", data["Rate"].mean())
print("Average Cost for Two:", data["Approx_cost(for two people)"].mean())
print("Total Restaurants:", data["Name"].nunique())

# %%
# Top restaurant types by rating

top_types = (
    df.groupby("rest_type")["rate"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

print(top_types)

# %%
# Most common cuisines
top_cuisines = df["cuisines"].value_counts().head(10)
print(top_cuisines)

# %%
import matplotlib.pyplot as plt

location_counts.plot(kind="bar")
plt.title("Top Restaurant Locations")
plt.xlabel("Location")
plt.ylabel("Number of Restaurants")
plt.xticks(rotation=45)
plt.show()
